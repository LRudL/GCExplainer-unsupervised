# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from gcf import *
from graph import *
from graph_gen import bhshapes
import graph_gen as gg
import matplotlib.pyplot as plt
import pandas as pd
import torch as t
import torch_geometric as pyg
from k_means_gnn import KmeansConceptFinder

# %%
graph = Graph(gg.bhshapes(300, 80))

# %%
kmcf = KmeansConceptFinder(4)

# %%
concepts = kmcf.find_concepts(graph, "../do_not_commit_this_file")
# Out:
# Epoch 0: loss = 1748.92529296875, cluster_counts=tensor([700.])
# Epoch 1: loss = 1600.4595947265625, cluster_counts=tensor([700.])
# Epoch 2: loss = 1458.7171630859375, cluster_counts=tensor([700.])
# Epoch 3: loss = 1324.6912841796875, cluster_counts=tensor([700.])
# Epoch 4: loss = 1197.387939453125, cluster_counts=tensor([700.])
# Epoch 5: loss = 1075.6708984375, cluster_counts=tensor([700.])
# Epoch 6: loss = 958.5056762695312, cluster_counts=tensor([700.])
# Epoch 7: loss = 844.5101318359375, cluster_counts=tensor([700.])
# Epoch 8: loss = 733.1742553710938, cluster_counts=tensor([700.])
# Epoch 9: loss = 626.035888671875, cluster_counts=tensor([700.])
# Epoch 10: loss = 526.7582397460938, cluster_counts=tensor([700.])
# Epoch 11: loss = 440.1480712890625, cluster_counts=tensor([700.])
# Epoch 12: loss = 369.970947265625, cluster_counts=tensor([700.])
# Epoch 13: loss = 316.287353515625, cluster_counts=tensor([700.])
# Epoch 14: loss = 278.5091552734375, cluster_counts=tensor([700.])
# Epoch 15: loss = 258.32647705078125, cluster_counts=tensor([700.])
# Epoch 16: loss = 257.3765869140625, cluster_counts=tensor([700.])
# Epoch 17: loss = 268.8426513671875, cluster_counts=tensor([700.])
# Epoch 18: loss = 280.1490783691406, cluster_counts=tensor([700.])
# Epoch 19: loss = 285.41583251953125, cluster_counts=tensor([700.])
# Epoch 20: loss = 283.88055419921875, cluster_counts=tensor([700.])
# Epoch 21: loss = 276.1867980957031, cluster_counts=tensor([700.])
# Epoch 22: loss = 263.4888000488281, cluster_counts=tensor([700.])
# Epoch 23: loss = 247.01998901367188, cluster_counts=tensor([700.])
# Epoch 24: loss = 228.31771850585938, cluster_counts=tensor([700.])
# Epoch 25: loss = 209.63763427734375, cluster_counts=tensor([700.])
# Epoch 26: loss = 194.06736755371094, cluster_counts=tensor([700.])
# Epoch 27: loss = 185.0559844970703, cluster_counts=tensor([700.])
# Epoch 28: loss = 183.87338256835938, cluster_counts=tensor([700.])
# Epoch 29: loss = 187.2103271484375, cluster_counts=tensor([700.])
# Epoch 30: loss = 190.36900329589844, cluster_counts=tensor([700.])
# Epoch 31: loss = 190.79931640625, cluster_counts=tensor([700.])
# Epoch 32: loss = 188.486572265625, cluster_counts=tensor([700.])
# Epoch 33: loss = 184.44842529296875, cluster_counts=tensor([700.])
# Epoch 34: loss = 179.4430389404297, cluster_counts=tensor([700.])
# Epoch 35: loss = 173.90756225585938, cluster_counts=tensor([700.])
# Epoch 36: loss = 168.29539489746094, cluster_counts=tensor([700.])
# Epoch 37: loss = 163.3638458251953, cluster_counts=tensor([700.])
# Epoch 38: loss = 159.7368927001953, cluster_counts=tensor([700.])
# Epoch 39: loss = 157.68238830566406, cluster_counts=tensor([700.])
# Epoch 40: loss = 157.5887451171875, cluster_counts=tensor([700.])
# Epoch 41: loss = 159.58843994140625, cluster_counts=tensor([700.])
# Epoch 42: loss = 161.25851440429688, cluster_counts=tensor([700.])
# Epoch 43: loss = 159.55203247070312, cluster_counts=tensor([700.])
# Epoch 44: loss = 154.43328857421875, cluster_counts=tensor([700.])
# Epoch 45: loss = 148.58201599121094, cluster_counts=tensor([700.])
# Epoch 46: loss = 146.4595489501953, cluster_counts=tensor([700.])
# Epoch 47: loss = 148.7678680419922, cluster_counts=tensor([700.])
# Epoch 48: loss = 150.4815216064453, cluster_counts=tensor([700.])
# Epoch 49: loss = 150.25335693359375, cluster_counts=tensor([700.])
# Epoch 50: loss = 148.71414184570312, cluster_counts=tensor([700.])
# Epoch 51: loss = 146.54205322265625, cluster_counts=tensor([700.])
# Epoch 52: loss = 144.43296813964844, cluster_counts=tensor([700.])
# Epoch 53: loss = 143.34474182128906, cluster_counts=tensor([700.])
# Epoch 54: loss = 142.9875946044922, cluster_counts=tensor([700.])
# Epoch 55: loss = 141.90855407714844, cluster_counts=tensor([700.])
# Epoch 56: loss = 141.12258911132812, cluster_counts=tensor([700.])
# Epoch 57: loss = 140.9235076904297, cluster_counts=tensor([700.])
# Epoch 58: loss = 140.6558380126953, cluster_counts=tensor([700.])
# Epoch 59: loss = 139.60321044921875, cluster_counts=tensor([700.])
# Epoch 60: loss = 138.28408813476562, cluster_counts=tensor([700.])
# Epoch 61: loss = 137.5354766845703, cluster_counts=tensor([700.])
# Epoch 62: loss = 137.4324493408203, cluster_counts=tensor([700.])
# Epoch 63: loss = 136.99586486816406, cluster_counts=tensor([700.])
# Epoch 64: loss = 136.0413055419922, cluster_counts=tensor([700.])
# Epoch 65: loss = 135.46546936035156, cluster_counts=tensor([700.])
# Epoch 66: loss = 134.78834533691406, cluster_counts=tensor([700.])
# Epoch 67: loss = 134.10891723632812, cluster_counts=tensor([700.])
# Epoch 68: loss = 133.53233337402344, cluster_counts=tensor([700.])
# Epoch 69: loss = 133.26107788085938, cluster_counts=tensor([700.])
# Epoch 70: loss = 132.59490966796875, cluster_counts=tensor([700.])
# Epoch 71: loss = 131.81451416015625, cluster_counts=tensor([700.])
# Epoch 72: loss = 131.25514221191406, cluster_counts=tensor([700.])
# Epoch 73: loss = 130.97999572753906, cluster_counts=tensor([700.])
# Epoch 74: loss = 130.45602416992188, cluster_counts=tensor([700.])
# Epoch 75: loss = 129.75546264648438, cluster_counts=tensor([700.])
# Epoch 76: loss = 129.67782592773438, cluster_counts=tensor([700.])
# Epoch 77: loss = 128.98834228515625, cluster_counts=tensor([700.])
# Epoch 78: loss = 128.4541778564453, cluster_counts=tensor([700.])
# Epoch 79: loss = 128.02210998535156, cluster_counts=tensor([700.])
# Epoch 80: loss = 127.2287826538086, cluster_counts=tensor([700.])
# Epoch 81: loss = 126.75687408447266, cluster_counts=tensor([700.])
# Epoch 82: loss = 126.30972290039062, cluster_counts=tensor([700.])
# Epoch 83: loss = 125.6761703491211, cluster_counts=tensor([700.])
# Epoch 84: loss = 125.61316680908203, cluster_counts=tensor([700.])
# Epoch 85: loss = 125.31362915039062, cluster_counts=tensor([700.])
# Epoch 86: loss = 124.22000885009766, cluster_counts=tensor([700.])
# Epoch 87: loss = 123.87068176269531, cluster_counts=tensor([700.])
# Epoch 88: loss = 123.6478271484375, cluster_counts=tensor([700.])
# Epoch 89: loss = 122.77535247802734, cluster_counts=tensor([700.])
# Epoch 90: loss = 122.34810638427734, cluster_counts=tensor([700.])
# Epoch 91: loss = 121.87102508544922, cluster_counts=tensor([700.])
# Epoch 92: loss = 121.27980041503906, cluster_counts=tensor([700.])
# Epoch 93: loss = 120.82006072998047, cluster_counts=tensor([700.])
# Epoch 94: loss = 120.15477752685547, cluster_counts=tensor([700.])
# Epoch 95: loss = 119.7328109741211, cluster_counts=tensor([700.])
# Epoch 96: loss = 119.16336822509766, cluster_counts=tensor([700.])
# Epoch 97: loss = 118.6237564086914, cluster_counts=tensor([700.])
# Epoch 98: loss = 118.35174560546875, cluster_counts=tensor([700.])
# Epoch 99: loss = 117.5259017944336, cluster_counts=tensor([700.])
# Epoch 100: loss = 117.01502990722656, cluster_counts=tensor([700.])
# Epoch 101: loss = 116.78446197509766, cluster_counts=tensor([700.])
# Epoch 102: loss = 115.96096801757812, cluster_counts=tensor([700.])
# Epoch 103: loss = 115.66972351074219, cluster_counts=tensor([700.])
# Epoch 104: loss = 115.17146301269531, cluster_counts=tensor([700.])
# Epoch 105: loss = 114.34422302246094, cluster_counts=tensor([700.])
# Epoch 106: loss = 114.02613067626953, cluster_counts=tensor([700.])
# Epoch 107: loss = 113.62753295898438, cluster_counts=tensor([700.])
# Epoch 108: loss = 112.88995361328125, cluster_counts=tensor([700.])
# Epoch 109: loss = 112.51537322998047, cluster_counts=tensor([700.])
# Epoch 110: loss = 111.94467163085938, cluster_counts=tensor([700.])
# Epoch 111: loss = 111.38713836669922, cluster_counts=tensor([700.])
# Epoch 112: loss = 110.93028259277344, cluster_counts=tensor([700.])
# Epoch 113: loss = 110.26744842529297, cluster_counts=tensor([700.])
# Epoch 114: loss = 109.8812255859375, cluster_counts=tensor([700.])
# Epoch 115: loss = 109.2624282836914, cluster_counts=tensor([700.])
# Epoch 116: loss = 108.58912658691406, cluster_counts=tensor([700.])
# Epoch 117: loss = 108.25194549560547, cluster_counts=tensor([700.])
# Epoch 118: loss = 107.8116455078125, cluster_counts=tensor([700.])
# Epoch 119: loss = 107.14469146728516, cluster_counts=tensor([700.])
# Epoch 120: loss = 106.73841094970703, cluster_counts=tensor([700.])
# Epoch 121: loss = 106.06303405761719, cluster_counts=tensor([700.])
# Epoch 122: loss = 105.57425689697266, cluster_counts=tensor([700.])
# Epoch 123: loss = 105.10360717773438, cluster_counts=tensor([700.])
# Epoch 124: loss = 104.4152603149414, cluster_counts=tensor([700.])
# Epoch 125: loss = 104.12330627441406, cluster_counts=tensor([700.])
# Epoch 126: loss = 103.64311218261719, cluster_counts=tensor([700.])
# Epoch 127: loss = 102.87199401855469, cluster_counts=tensor([700.])
# Epoch 128: loss = 102.43830108642578, cluster_counts=tensor([700.])
# Epoch 129: loss = 101.88790893554688, cluster_counts=tensor([700.])
# Epoch 130: loss = 101.35364532470703, cluster_counts=tensor([700.])
# Epoch 131: loss = 100.88336181640625, cluster_counts=tensor([700.])
# Epoch 132: loss = 100.29988098144531, cluster_counts=tensor([700.])
# Epoch 133: loss = 99.6484375, cluster_counts=tensor([700.])
# Epoch 134: loss = 99.0420913696289, cluster_counts=tensor([700.])
# Epoch 135: loss = 98.5828857421875, cluster_counts=tensor([700.])
# Epoch 136: loss = 98.09085083007812, cluster_counts=tensor([700.])
# Epoch 137: loss = 97.46276092529297, cluster_counts=tensor([700.])
# Epoch 138: loss = 96.94414520263672, cluster_counts=tensor([700.])
# Epoch 139: loss = 96.49931335449219, cluster_counts=tensor([700.])
# Epoch 140: loss = 95.96660614013672, cluster_counts=tensor([700.])
# Epoch 141: loss = 95.32691192626953, cluster_counts=tensor([700.])
# Epoch 142: loss = 94.70921325683594, cluster_counts=tensor([700.])
# Epoch 143: loss = 94.20670318603516, cluster_counts=tensor([700.])
# Epoch 144: loss = 93.6982650756836, cluster_counts=tensor([700.])
# Epoch 145: loss = 93.10924530029297, cluster_counts=tensor([700.])
# Epoch 146: loss = 92.56727600097656, cluster_counts=tensor([700.])
# Epoch 147: loss = 91.94911193847656, cluster_counts=tensor([700.])
# Epoch 148: loss = 91.42343139648438, cluster_counts=tensor([700.])
# Epoch 149: loss = 90.90642547607422, cluster_counts=tensor([700.])
# Epoch 150: loss = 90.3604965209961, cluster_counts=tensor([700.])
# Epoch 151: loss = 89.7720947265625, cluster_counts=tensor([700.])
# Epoch 152: loss = 89.16189575195312, cluster_counts=tensor([700.])
# Epoch 153: loss = 88.59391784667969, cluster_counts=tensor([700.])
# Epoch 154: loss = 88.10700988769531, cluster_counts=tensor([700.])
# Epoch 155: loss = 87.51718139648438, cluster_counts=tensor([700.])
# Epoch 156: loss = 86.9303970336914, cluster_counts=tensor([700.])
# Epoch 157: loss = 86.33409881591797, cluster_counts=tensor([700.])
# Epoch 158: loss = 85.7784652709961, cluster_counts=tensor([700.])
# Epoch 159: loss = 85.24108123779297, cluster_counts=tensor([700.])
# Epoch 160: loss = 84.6949234008789, cluster_counts=tensor([700.])
# Epoch 161: loss = 84.08657836914062, cluster_counts=tensor([700.])
# Epoch 162: loss = 83.50239562988281, cluster_counts=tensor([700.])
# Epoch 163: loss = 82.9197006225586, cluster_counts=tensor([700.])
# Epoch 164: loss = 82.39064025878906, cluster_counts=tensor([700.])
# Epoch 165: loss = 81.79995727539062, cluster_counts=tensor([700.])
# Epoch 166: loss = 81.23233032226562, cluster_counts=tensor([700.])
# Epoch 167: loss = 80.6373291015625, cluster_counts=tensor([700.])
# Epoch 168: loss = 80.0639419555664, cluster_counts=tensor([700.])
# Epoch 169: loss = 79.48481750488281, cluster_counts=tensor([700.])
# Epoch 170: loss = 78.92549133300781, cluster_counts=tensor([700.])
# Epoch 171: loss = 78.34619140625, cluster_counts=tensor([700.])
# Epoch 172: loss = 77.7786636352539, cluster_counts=tensor([700.])
# Epoch 173: loss = 77.17147827148438, cluster_counts=tensor([700.])
# Epoch 174: loss = 76.57852172851562, cluster_counts=tensor([700.])
# Epoch 175: loss = 76.0062026977539, cluster_counts=tensor([700.])
# Epoch 176: loss = 75.48956298828125, cluster_counts=tensor([700.])
# Epoch 177: loss = 74.8772964477539, cluster_counts=tensor([700.])
# Epoch 178: loss = 74.24632263183594, cluster_counts=tensor([700.])
# Epoch 179: loss = 73.63597869873047, cluster_counts=tensor([700.])
# Epoch 180: loss = 73.10847473144531, cluster_counts=tensor([700.])
# Epoch 181: loss = 72.58606719970703, cluster_counts=tensor([700.])
# Epoch 182: loss = 71.96392059326172, cluster_counts=tensor([700.])
# Epoch 183: loss = 71.30526733398438, cluster_counts=tensor([700.])
# Epoch 184: loss = 70.70744323730469, cluster_counts=tensor([700.])
# Epoch 185: loss = 70.19124603271484, cluster_counts=tensor([700.])
# Epoch 186: loss = 69.72282409667969, cluster_counts=tensor([700.])
# Epoch 187: loss = 69.02470397949219, cluster_counts=tensor([700.])
# Epoch 188: loss = 68.34058380126953, cluster_counts=tensor([700.])
# Epoch 189: loss = 67.76011657714844, cluster_counts=tensor([700.])
# Epoch 190: loss = 67.31620788574219, cluster_counts=tensor([700.])
# Epoch 191: loss = 66.77838897705078, cluster_counts=tensor([700.])
# Epoch 192: loss = 66.00631713867188, cluster_counts=tensor([700.])
# Epoch 193: loss = 65.40815734863281, cluster_counts=tensor([700.])
# Epoch 194: loss = 65.03651428222656, cluster_counts=tensor([700.])
# Epoch 195: loss = 64.29090118408203, cluster_counts=tensor([700.])
# Epoch 196: loss = 63.63450241088867, cluster_counts=tensor([700.])
# Epoch 197: loss = 63.07280349731445, cluster_counts=tensor([700.])
# Epoch 198: loss = 62.508689880371094, cluster_counts=tensor([700.])
# Epoch 199: loss = 62.00499725341797, cluster_counts=tensor([700.])
# AFTER UPDATE
# [[0.82334113 0.903028   0.10634249 0.45176286 0.39977905 0.9470809
#   0.6411419  0.13460734 0.23035331 0.48577744 0.943236   0.09405667
#   0.9179579  0.8918995  0.10317019 0.39133814]
#  [0.7166846  0.80899626 0.10186497 0.44093877 0.3935773  0.8486073
#   0.58136487 0.13459212 0.22727096 0.44711283 0.8524881  0.09600594
#   0.79029006 0.7941459  0.10395634 0.38250235]
#  [1.0424347  1.0994935  0.11122364 0.47455534 0.41481608 1.1330072
#   0.7547922  0.14576292 0.258085   0.56288075 1.1261494  0.10635898
#   1.1623251  1.0737538  0.1082784  0.4172178 ]
#  [0.7625553  0.8484604  0.10411967 0.4453753  0.39556643 0.8920846
#   0.6079943  0.13300768 0.22586107 0.46367085 0.8908967  0.09281587
#   0.8473496  0.83787894 0.10270527 0.3845763 ]]
# (array([0, 1, 2, 3], dtype=int32), array([225, 123,  12, 340]))
# Epoch 0: loss = 22.85711669921875, cluster_counts=tensor([225., 123.,  12., 340.])
# Epoch 1: loss = 25.79625129699707, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 2: loss = 23.012897491455078, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 3: loss = 23.51241683959961, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 4: loss = 24.13410758972168, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 5: loss = 23.740768432617188, cluster_counts=tensor([226., 123.,  11., 340.])
# Epoch 6: loss = 23.018054962158203, cluster_counts=tensor([225., 123.,  12., 340.])
# Epoch 7: loss = 22.786235809326172, cluster_counts=tensor([226., 123.,  11., 340.])
# Epoch 8: loss = 23.014862060546875, cluster_counts=tensor([221., 123.,  11., 345.])
# Epoch 9: loss = 23.08110809326172, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 10: loss = 22.84896469116211, cluster_counts=tensor([219., 123.,  11., 347.])
# Epoch 11: loss = 22.583913803100586, cluster_counts=tensor([218., 123.,  11., 348.])
# Epoch 12: loss = 22.54300308227539, cluster_counts=tensor([219., 123.,  11., 347.])
# Epoch 13: loss = 22.598678588867188, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 14: loss = 22.586856842041016, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 15: loss = 22.5046329498291, cluster_counts=tensor([221., 123.,  11., 345.])
# Epoch 16: loss = 22.415943145751953, cluster_counts=tensor([226., 123.,  11., 340.])
# Epoch 17: loss = 22.357433319091797, cluster_counts=tensor([221., 123.,  11., 345.])
# Epoch 18: loss = 22.277135848999023, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 19: loss = 22.19843292236328, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 20: loss = 22.183515548706055, cluster_counts=tensor([218., 123.,  11., 348.])
# Epoch 21: loss = 22.154356002807617, cluster_counts=tensor([218., 123.,  11., 348.])
# Epoch 22: loss = 22.057209014892578, cluster_counts=tensor([219., 123.,  11., 347.])
# Epoch 23: loss = 21.961368560791016, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 24: loss = 21.919084548950195, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 25: loss = 21.90378189086914, cluster_counts=tensor([221., 123.,  11., 345.])
# Epoch 26: loss = 21.86142921447754, cluster_counts=tensor([221., 123.,  11., 345.])
# Epoch 27: loss = 21.77597427368164, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 28: loss = 21.681968688964844, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 29: loss = 21.635875701904297, cluster_counts=tensor([220., 123.,  11., 346.])
# Epoch 30: loss = 21.632482528686523, cluster_counts=tensor([221., 123.,  10., 346.])
# Epoch 31: loss = 21.60489273071289, cluster_counts=tensor([221., 123.,  10., 346.])
# Epoch 32: loss = 21.552217483520508, cluster_counts=tensor([221., 123.,  10., 346.])
# Epoch 33: loss = 21.518922805786133, cluster_counts=tensor([221., 123.,  10., 346.])
# Epoch 34: loss = 21.50144386291504, cluster_counts=tensor([221., 123.,  10., 346.])
# Epoch 35: loss = 21.475265502929688, cluster_counts=tensor([221., 123.,  10., 346.])
# Epoch 36: loss = 21.440479278564453, cluster_counts=tensor([221., 123.,  10., 346.])
# Epoch 37: loss = 21.402610778808594, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 38: loss = 21.364978790283203, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 39: loss = 21.32907485961914, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 40: loss = 21.295764923095703, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 41: loss = 21.259122848510742, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 42: loss = 21.21467399597168, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 43: loss = 21.1771183013916, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 44: loss = 21.145099639892578, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 45: loss = 21.106178283691406, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 46: loss = 21.063579559326172, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 47: loss = 21.029935836791992, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 48: loss = 21.000093460083008, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 49: loss = 20.964431762695312, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 50: loss = 20.92749786376953, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 51: loss = 20.902217864990234, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 52: loss = 20.87459945678711, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 53: loss = 20.837486267089844, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 54: loss = 20.797727584838867, cluster_counts=tensor([222., 123.,   9., 346.])
# Epoch 55: loss = 20.76515007019043, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 56: loss = 20.733060836791992, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 57: loss = 20.70009994506836, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 58: loss = 20.6665096282959, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 59: loss = 20.634916305541992, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 60: loss = 20.60256576538086, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 61: loss = 20.56922721862793, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 62: loss = 20.5374813079834, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 63: loss = 20.505653381347656, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 64: loss = 20.472896575927734, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 65: loss = 20.440563201904297, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 66: loss = 20.408462524414062, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 67: loss = 20.377056121826172, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 68: loss = 20.34451675415039, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 69: loss = 20.312753677368164, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 70: loss = 20.281103134155273, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 71: loss = 20.249835968017578, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 72: loss = 20.218353271484375, cluster_counts=tensor([220., 123.,   9., 348.])
# Epoch 73: loss = 20.18660545349121, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 74: loss = 20.155616760253906, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 75: loss = 20.124435424804688, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 76: loss = 20.093341827392578, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 77: loss = 20.06279754638672, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 78: loss = 20.032211303710938, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 79: loss = 20.001338958740234, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 80: loss = 19.971317291259766, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 81: loss = 19.94130516052246, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 82: loss = 19.910980224609375, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 83: loss = 19.881088256835938, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 84: loss = 19.851287841796875, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 85: loss = 19.82160186767578, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 86: loss = 19.792081832885742, cluster_counts=tensor([221., 123.,   9., 347.])
# Epoch 87: loss = 19.762405395507812, cluster_counts=tensor([221., 120.,   9., 350.])
# Epoch 88: loss = 19.732824325561523, cluster_counts=tensor([221., 120.,   9., 350.])
# Epoch 89: loss = 19.70325469970703, cluster_counts=tensor([221., 120.,   9., 350.])
# Epoch 90: loss = 19.6739444732666, cluster_counts=tensor([221., 120.,   9., 350.])
# Epoch 91: loss = 19.644668579101562, cluster_counts=tensor([226., 120.,   9., 345.])
# Epoch 92: loss = 19.612401962280273, cluster_counts=tensor([226., 115.,   9., 350.])
# Epoch 93: loss = 19.580102920532227, cluster_counts=tensor([226., 115.,   9., 350.])
# Epoch 94: loss = 19.550973892211914, cluster_counts=tensor([226., 115.,   9., 350.])
# Epoch 95: loss = 19.518314361572266, cluster_counts=tensor([226., 115.,   9., 350.])
# Epoch 96: loss = 19.4898738861084, cluster_counts=tensor([226., 115.,   9., 350.])
# Epoch 97: loss = 19.455028533935547, cluster_counts=tensor([226., 115.,   9., 350.])
# Epoch 98: loss = 19.430110931396484, cluster_counts=tensor([226., 115.,   9., 350.])
# Epoch 99: loss = 19.39656639099121, cluster_counts=tensor([226., 115.,   9., 350.])

# %%
[len(concept) for concept in concepts]
# Out:
# [226, 115, 9, 350]

# %%
graph.draw_around_node(44, steps=2)

# %%
kmcf.draw_concepts()
# Out:
# Each row is a concept. Each item in a row is an example of that concept.
# /home/lrudl/Dropbox/Rudolf/Cambridge/22-23/rlgn/GCExplainer-unsupervised/src/gcf.py:73: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
